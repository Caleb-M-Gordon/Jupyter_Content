# %% [markdown]
# # Assignment #3

# %% [markdown]
# This exercise invites you to build and compare two popular classification models—Logistic Regression and Support Vector Machine (SVM)—using the Wine dataset from the UCI Machine Learning Repository. The Wine dataset, which concerns the chemical analysis of wines grown in the same region in Italy but derived from three different cultivars, is an interesting dataset for this exercise.
#
# Note that this is not the same dataset we used in class that had wine quality as the y value. It seems like machine learning researchers spend a lot of time creating datasets about wine... 🤔
#
# The goal is to develop a model to classify wines by region of origin ('Class' in the dataset).
#
# This assignment should be done in groups of 2-4 people, not on your own. Please reply on the announcement for the assignment if you need help finding a group.

# %% [markdown]
# Overview
#
# In this exercise, you will:
#
# Load the Wine dataset directly from the UCI repository.
# Perform a brief exploratory analysis: Visualize key feature distributions and class separations.
# Prepare your data: Carry out a minimal train-test split.
# Design and tune classification models: Set up logistic regression and SVM classifiers and explore hyperparameter tuning.
# Evaluate and compare: Use appropriate metrics and visualization techniques to compare the models.

# %% [markdown]
# #### 1.  Accessing the Data

# %% [markdown]
# Load the Wine dataset directly into your Jupyter Notebook with the following snippet:

# %%
import pandas as pd

#data = 'data/wine.csv'
# Alternatively, it can be downloaded directly
data = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"

# The dataset has no header; add column names as provided in the UCI repository documentation.
columns = ['Class', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_of_ash', 'Magnesium',
           'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthocyanins',
           'Color_intensity', 'Hue', 'OD280/OD315_of_diluted_wines', 'Proline']
data = pd.read_csv(data, header=None, names=columns)
data.head()
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280/OD315_of_diluted_wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %% [markdown]
# #### 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# • Visualization: Use scatter plots or pair plots (with tools like seaborn’s pairplot) to explore how the features distinguish between the three wine classes.

# %% [markdown]
# • Feature Insight: Briefly analyze key chemical properties and their distributions across the classes.
